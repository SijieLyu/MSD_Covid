# %%
import numpy as np
import pandas as pd
import tabula

# %%
FILE = 'https://mehlvilleschooldistrict.com/common/pages/DisplayFile.aspx?itemId=10088259'

table = tabula.read_pdf(FILE, pages=1)
df = table[0]
df = df.iloc[6:-2, :-4].reset_index(drop=True)

cols=['school','staff_newPos','staff_offCampus','stu_newPos','stu_offCampus','Stu_CloseContactAllowedOnCampus']
df.columns = cols
df['date'] = np.datetime64('2022-01-02')

df
# Out:
#                               school staff_newPos staff_offCampus stu_newPos  \
# 0   John Cary Early Childhood Center            6               6          1
# 1          Beasley Elementary School            2               2          0
# 2         Bierbaum Elementary School            3               4          2
# 3           Blades Elementary School            6               6          6
# 4           Forder Elementary School            3               4          2
# 5         Hagemann Elementary School            2               2          2
# 6           MOSAIC Elementary School            3               3          1
# 7         Oakville Elementary School            2               2          0
# 8            Point Elementary School            1               1          2
# 9           Rogers Elementary School            1               1          3
# 10       Trautwein Elementary School            2               2          5
# ...

# %%
# df.to_csv('2021-01-02.csv', index=False)
